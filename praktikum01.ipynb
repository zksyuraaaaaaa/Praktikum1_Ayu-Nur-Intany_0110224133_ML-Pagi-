# %%
import pandas as pd

# 1. Baca file dataset lain (misalnya day.csv)
df = pd.read_csv('../Dataset Praktikum/day.csv', sep=',')

# Tampilkan 5 baris pertama
print("Dataset asli:")
print(df.head())

# 2. Buat dataframe baru df1 dengan kolom tertentu
df1 = df[['instant', 'dteday', 'season', 'temp', 'hum', 'windspeed']]

# 3. Cetak dataframe baru ke layar
print("\nDataframe baru (df1):")
print(df1.head())

# 4. Simpan dataframe baru ke file CSV
df1.to_csv('../data/latihan01.csv', index=False)

print("\nDataframe baru berhasil disimpan sebagai latihan01.csv di folder data")
# Out:
# Dataset asli:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600
#
# ...

# %%
import pandas as pd

# Baca kembali file CSV yang sudah disimpan
df_check = pd.read_csv('../Data/latihan01.csv')

print("Isi dataframe dari latihan01.csv:")
print(df_check.head())
# Out:
# Isi dataframe dari latihan01.csv:
#    instant      dteday  season      temp       hum  windspeed
# 0        1  2011-01-01       1  0.344167  0.805833   0.160446
# 1        2  2011-01-02       1  0.363478  0.696087   0.248539
# 2        3  2011-01-03       1  0.196364  0.437273   0.248309
# 3        4  2011-01-04       1  0.200000  0.590435   0.160296
# 4        5  2011-01-05       1  0.226957  0.436957   0.186900
